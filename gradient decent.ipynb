# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadrajput99/EDA-Using-Pandas/blob/main/gradient%20decent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def gradient_decent(x,y):
  m_curr=b_curr=0
  iterations=10000
  n=len(x)
  learning_rate=0.01

  for i in range(iterations):
    yp=m_curr*x + b_curr
    cost=(1/n) *sum([val**2 for val in (y-yp)])
    md=-(2/n) *sum(x*(y-yp))
    bd=-(2/n) *sum((y-yp))
    m_curr= m_curr - learning_rate*md
    b_curr= b_curr - learning_rate*bd
    print("m {}, b{}, cost{}, iteration{}".format(m_curr,b_curr,cost,i))
  pass


x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])

gradient_decent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 2.000000027748417, b2.9999998998194113, cost1.8391702597594785e-15, iteration5000
# m 2.0000000276546004, b2.999999900158118, cost1.826754969563614e-15, iteration5001
# m 2.0000000275611014, b2.9999999004956797, cost1.81442346865097e-15, iteration5002
# m 2.000000027467918, b2.9999999008321, cost1.802175231104541e-15, iteration5003
# m 2.0000000273750502, b2.999999901167383, cost1.7900096116236763e-15, iteration5004
# m 2.0000000272824963, b2.999999901501532, cost1.7779261911764547e-15, iteration5005
# m 2.0000000271902554, b2.9999999018345513, cost1.7659243149753253e-15, iteration5006
# m 2.0000000270983262, b2.999999902166445, cost1.7540034779000308e-15, iteration5007
# m 2.0000000270067075, b2.9999999024972164, cost1.7421631063296812e-15, iteration5008
# m 2.000000026915399, b2.9999999028268696, cost1.7304026364503835e-15, iteration5009
# m 2.0000000268243987, b2.999999903155408, cost1.7187215496941953e-15, iteration5010
# ...
