# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadrajput99/EDA-Using-Pandas/blob/main/Black%20friday%20sale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
train_df=pd.read_csv('/content/test.csv')
train_df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
train_df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %%
train_df.drop(['User_ID'],axis=1,inplace=True)
train_df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00128942      M  46-50           7             B
# 1       P00113442      M  26-35          17             C
# 2       P00288442      F  36-45           1             B
# 3       P00145342      F  36-45           1             B
# 4       P00053842      F  26-35           1             C
# ...           ...    ...    ...         ...           ...
# 233594  P00118942      F  26-35          15             B
# 233595  P00254642      F  26-35          15             B
# 233596  P00031842      F  26-35          15             B
# 233597  P00124742      F  46-50           1             C
# 233598  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# ...

# %%
train_df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00128942      M  46-50           7             B
# 1       P00113442      M  26-35          17             C
# 2       P00288442      F  36-45           1             B
# 3       P00145342      F  36-45           1             B
# 4       P00053842      F  26-35           1             C
# ...           ...    ...    ...         ...           ...
# 233594  P00118942      F  26-35          15             B
# 233595  P00254642      F  26-35          15             B
# 233596  P00031842      F  26-35          15             B
# 233597  P00124742      F  46-50           1             C
# 233598  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# ...

# %%
train_df['Gender']=train_df['Gender'].map({'f':0, 'M':1})
train_df
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 0       P00128942     1.0  46-50           7             B
# 1       P00113442     1.0  26-35          17             C
# 2       P00288442     NaN  36-45           1             B
# 3       P00145342     NaN  36-45           1             B
# 4       P00053842     NaN  26-35           1             C
# ...           ...     ...    ...         ...           ...
# 233594  P00118942     NaN  26-35          15             B
# 233595  P00254642     NaN  26-35          15             B
# 233596  P00031842     NaN  26-35          15             B
# 233597  P00124742     NaN  46-50           1             C
# 233598  P00316642     NaN  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# ...

# %%
train_df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                         57827
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
df_train=pd.read_csv('/content/train.csv')
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df=train_df.append(df_train)
df
# Out:
# <ipython-input-20-de923c189cce>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=train_df.append(df_train)
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00128942    1.0  46-50           7             B
# 1       P00113442    1.0  26-35          17             C
# 2       P00288442    NaN  36-45           1             B
# 3       P00145342    NaN  36-45           1             B
# 4       P00053842    NaN  26-35           1             C
# ...           ...    ...    ...         ...           ...
# 550063  P00372445      M  51-55          13             B
# 550064  P00375436      F  26-35           1             C
# 550065  P00375436      F  26-35          15             B
# 550066  P00375436      F    55+           1             C
# 550067  P00371644      F  46-50           0             B
#
# ...

# %%
df['Age'].unique()
# Out:
# array(['46-50', '26-35', '36-45', '18-25', '51-55', '55+', '0-17'],
#       dtype=object)

# %%
df['Age']=df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

#pd.get_dummies(df['Age'],drop_first=True)

# %%
df.head()
# Out:
#   Product_ID Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0  P00128942    1.0  NaN           7             B                          2
# 1  P00113442    1.0  NaN          17             C                          0
# 2  P00288442    NaN  NaN           1             B                         4+
# 3  P00145342    NaN  NaN           1             B                         4+
# 4  P00053842    NaN  NaN           1             C                          1
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               1                   1                11.0                 NaN
# 1               0                   3                 5.0                 NaN
# 2               1                   5                14.0                 NaN
# 3               1                   4                 9.0                 NaN
# 4               0                   4                 5.0                12.0
#
#    User_ID  Purchase
# ...

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['Age']= label_encoder.fit_transform(df['Age'])

df['Age'].unique()
# Out:
# array([0])

# %%
df.head()
# Out:
#   Product_ID Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0  P00128942    1.0    0           7             B                          2
# 1  P00113442    1.0    0          17             C                          0
# 2  P00288442    NaN    0           1             B                         4+
# 3  P00145342    NaN    0           1             B                         4+
# 4  P00053842    NaN    0           1             C                          1
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               1                   1                11.0                 NaN
# 1               0                   3                 5.0                 NaN
# 2               1                   5                14.0                 NaN
# 3               1                   4                 9.0                 NaN
# 4               0                   4                 5.0                12.0
#
#    User_ID  Purchase
# ...

# %%
df_city=pd.get_dummies(df['City_Category'],drop_first=True)

# %%
df_city.head()
# Out:
#    B  C
# 0  1  0
# 1  0  1
# 2  1  0
# 3  1  0
# 4  0  1

# %%
pd.concat([df,df_city],axis=1)
# Out:
#        Product_ID Gender  Age  Occupation City_Category  \
# 0       P00128942    1.0    0           7             B
# 1       P00113442    1.0    0          17             C
# 2       P00288442    NaN    0           1             B
# 3       P00145342    NaN    0           1             B
# 4       P00053842    NaN    0           1             C
# ...           ...    ...  ...         ...           ...
# 550063  P00372445      M    0          13             B
# 550064  P00375436      F    0           1             C
# 550065  P00375436      F    0          15             B
# 550066  P00375436      F    0           1             C
# 550067  P00371644      F    0           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# ...

# %%
df.drop('City_Category',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                         57827
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# User_ID                       233599
# Purchase                      233599
# dtype: int64
