# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadrajput99/EDA-Using-Pandas/blob/main/prediction%20of%20salery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
df=pd.read_csv('/content/hiring.csv')
df
# Out:
#   experience  test_score_out_of_100  interview score out of 100  dollares
# 0        NaN                    8.0                           9     50000
# 1        NaN                    8.0                           6     45000
# 2       five                    6.0                           7     60000
# 3        two                   10.0                          10     65000
# 4      seven                    9.0                           6     70000
# 5      three                    7.0                          10     62000
# 6        ten                    NaN                           7     72000
# 7     eleven                    7.0                           8     80000

# %%
import math
score_median=math.floor(df.test_score_out_of_100.median())
score_median
# Out:
# 8

# %%
df.test_score_out_of_100=df.test_score_out_of_100.fillna(score_median)

# %%
df
# Out:
#    experience  test_score_out_of_100  interview score out of 100  dollares
# 0           0                    8.0                           9     50000
# 1           0                    8.0                           6     45000
# 2           5                    6.0                           7     60000
# 3           2                   10.0                          10     65000
# 4           7                    9.0                           6     70000
# 5           3                    7.0                          10     62000
# 6          10                    8.0                           7     72000
# 7          11                    7.0                           8     80000

# %%
df.experience=df.experience.fillna('zero')

# %%
df
# Out:
#   experience  test_score_out_of_100  interview score out of 100  dollares
# 0       zero                    8.0                           9     50000
# 1       zero                    8.0                           6     45000
# 2       five                    6.0                           7     60000
# 3        two                   10.0                          10     65000
# 4      seven                    9.0                           6     70000
# 5      three                    7.0                          10     62000
# 6        ten                    NaN                           7     72000
# 7     eleven                    7.0                           8     80000

# %%
df['experience'] = df['experience'].astype(str)

# %%
from word2number import w2n

# %%
# !pip install word2number

# %%
from word2number import w2n

# %%
df.experience = df.experience.apply(w2n.word_to_num)

# %%
df
# Out:
#    experience  test_score_out_of_100  interview score out of 100  dollares
# 0           0                    8.0                           9     50000
# 1           0                    8.0                           6     45000
# 2           5                    6.0                           7     60000
# 3           2                   10.0                          10     65000
# 4           7                    9.0                           6     70000
# 5           3                    7.0                          10     62000
# 6          10                    NaN                           7     72000
# 7          11                    7.0                           8     80000

# %%
import sklearn.linear_model as linear_model

reg = linear_model.LinearRegression()  # Instantiate the LinearRegression class
reg.fit(df[['experience', 'test_score_out_of_100', 'interview score out of 100']], df['dollares'])  # Fit the model with the specified features and target variable
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %%
reg.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92002.18340611])
